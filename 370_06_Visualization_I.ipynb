# %% [markdown]
# # SI 370 - Visualization I

# %% [markdown]
# ## Visualization for Data Scientists

# %% [markdown]
# We're going to ask a special virtual guest lecturer to provide some background on data visualization.  Together, we'll watch [a brief (8-video) by Dr. Chris Brooks](
# https://www.coursera.org/learn/python-plotting/lecture/qrqqa/tools-for-thinking-about-design-alberto-cairo)
# and pause it several times to answer the following questions:

# %% [markdown]
# ## <font color="red">Q1a: As someone who is studying data science, who are you trying to reach through your visualizations?

# %% [markdown]
# (replace this with your response)

# %% [markdown]
# ## <font color="red">Q1b: What sense can you make of this image?
# ![](resources/BrooksResearch.png)

# %% [markdown]
# (replace this with your response)

# %% [markdown]
# ## <font color="red">Q1c: How many different kinds of information can you see in the Minard graphic, and what are they?

# %% [markdown]
# ![](resources/Menard.png)

# %% [markdown]
# (replace this with your response)

# %% [markdown]
# ## Returning to Seaborn:
#
# https://seaborn.pydata.org/examples/index.html
#
# Take a look at the different visualizations that are possible.

# %% [markdown]
# ## <font color="red">Q2a: Provide the title, description, and URL of one of the visualizations that you find particularly interesting and explain why you find it interesting.

# %% [markdown]
# (replace this with your response)

# %% [markdown]
# ## <font color="red">Q2b: Given what we learned from Prof. Brooks, indicate 1-3 axes from Cairo's Visual Wheel where your chosen Seaborn visualization would likely score highly. Explain why.

# %% [markdown]
# ![](resources/CairoVisualWheel.png)

# %% [markdown]
# (replace this with your response)

# %% [markdown]
# ## Seaborn versus Matplotlib
# * Matplotlib
#      * Low-level, basis for many packages
#      * Painful to construct certain graphs
#      * Not Pandas friendly
#      * Not interactive
# * Seaborn
#      * Pandas friendlier
#      * Great for some stats plots

# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Remember our distplots:

# %%
sns.distplot(df.sepal_length)

# %% [markdown]
# Remove the kernel density estimate (KDE) curve from, and add a rug plot to the above plot.

# %%
# insert your code here

# %% [markdown]
# Now create plots for the other three variables

# %%
# insert your code here

# %% [markdown]
# We often want to see how variables vary with each other.  We'll get into the details
# in a few classes, but for now let's examine them visually.  In seaborn, we do this using
# the jointplot(). So, for example, if we wanted to look at the relationship between the
# distributions of sepal_length and sepal_width, we could do something like:

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=df)

# %% [markdown]
# It's a bit difficult to see where the interesting areas in the plot
# are, so it's worth trying a hexbin plot.  Go ahead and copy the above
# code block and add ```kind="hex"``` to the jointplot parameters.

# %%
# insert your code here
sns.jointplot(x='sepal_length',y='sepal_width',data=df,kind="hex")

# %% [markdown]
# Now, take a look at what happens when you set ```kind="kde"```

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=df,kind="kde")

# %% [markdown]
# Finally, you may want to look at all the numeric variables in your
# dataset. Use ```pairplot``` to do this:

# %%
sns.pairplot(df.query("species == 'setosa'"))

# %% [markdown]
# We can get fancier by using a different column to set the color (or "hue"):
#
# Try running the following code:

# %%
sns.pairplot(df,hue="species")

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", kind="line", ci=None, data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", kind="line", ci="sd",data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", kind="line", estimator=None, data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri, hue="event");

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri, hue="region", style="event");

# %%
df = pd.DataFrame(dict(time=pd.date_range("2017-4-9", periods=500),
                       value=np.random.randn(500).cumsum()))
df
# Out:
#           time      value
# 0   2017-04-09   1.042927
# 1   2017-04-10  -0.649546
# 2   2017-04-11  -1.552905
# 3   2017-04-12  -2.292828
# 4   2017-04-13  -3.107357
# 5   2017-04-14  -4.350789
# 6   2017-04-15  -4.672709
# 7   2017-04-16  -4.751016
# 8   2017-04-17  -4.573610
# 9   2017-04-18  -4.493982
# 10  2017-04-19  -4.171357
# 11  2017-04-20  -4.805700
# 12  2017-04-21  -5.284686
# 13  2017-04-22  -4.971240
# 14  2017-04-23  -4.422131
# 15  2017-04-24  -2.730838
# 16  2017-04-25  -4.204992
# 17  2017-04-26  -4.935839
# 18  2017-04-27  -5.096102
# 19  2017-04-28  -6.599487
# 20  2017-04-29  -7.023292
# 21  2017-04-30  -7.368293
# 22  2017-05-01  -7.632040
# 23  2017-05-02  -8.353506
# 24  2017-05-03  -9.275058
# 25  2017-05-04 -10.409145
# 26  2017-05-05 -10.537272
# 27  2017-05-06 -10.429837
# 28  2017-05-07 -10.381310
# 29  2017-05-08 -10.827147
# ..         ...        ...
# 470 2018-07-23  -7.613127
# 471 2018-07-24  -8.077503
# 472 2018-07-25  -9.300970
# 473 2018-07-26  -6.886188
# 474 2018-07-27  -6.240109
# 475 2018-07-28  -6.630826
# 476 2018-07-29  -5.453710
# 477 2018-07-30  -4.563182
# 478 2018-07-31  -3.984649
# 479 2018-08-01  -5.797542
# 480 2018-08-02  -5.441862
# 481 2018-08-03  -4.743514
# 482 2018-08-04  -3.663501
# 483 2018-08-05  -3.902280
# 484 2018-08-06  -4.281948
# 485 2018-08-07  -3.897795
# 486 2018-08-08  -3.702909
# 487 2018-08-09  -3.155943
# 488 2018-08-10  -3.090562
# 489 2018-08-11  -3.124734
# 490 2018-08-12  -3.197783
# 491 2018-08-13  -3.766218
# 492 2018-08-14  -2.635013
# 493 2018-08-15  -2.394704
# 494 2018-08-16  -3.499660
# 495 2018-08-17  -3.038482
# 496 2018-08-18  -2.975881
# 497 2018-08-19  -3.242306
# 498 2018-08-20  -4.176696
# 499 2018-08-21  -5.523374
#
# [500 rows x 2 columns]

# %%
g = sns.relplot(x="time", y="value", kind="line", data=df)

# %% [markdown]
# The x-axis looks squished, so it's worth digging down into matplotlib to
# fix this:

# %%
g = sns.relplot(x="time", y="value", kind="line", data=df)
g.fig.autofmt_xdate()
